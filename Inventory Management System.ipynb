# %%
print(" ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈")
print("╎⫷𝓦𝓮𝓵𝓬𝓸𝓶𝓮 T♥O 𝓢🎀𝓢𝓱𝓸𝓹⫸╎")
print(" ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈")
item_name=int(input("Enter➫1 For Name of the Item Present in Stock \nEnter➫2 For All Item Detail Of Price,Quantity,Colour,Retailer Name,Discount\nEnter➫3 If You Want To Order/Purchase Any Item\nEnter➫4 If You Want To Add New Item In Inventory\nEnter➫5 If You Want To Update Quatity(Increase/Decrease) In Inventory\nEnter➫6 For Refresh Item And Delete History Of Purchase and Add Item\nEnter➫7 For Remove Item From Store\n\nThanks for visit😊\n"))
if(item_name==6):
    con=str(input("Confirm➫Y/y To Delete History Of Add New Item In Inventory\nOr,Enter N/n➫If Not Want To delete\n"))
    if(con=='Y' or con=='y'):
        import json
        Item ={ 1 : {"Item Name" : "Book","Price Per Piece" : 10,"Quantity" : 10, "Colour" : "White cover","Retailer Name":"Aman","Give discout":2},
                2 : {"Item Name" : "Pen","Price Per Piece" : 5,"Quantity" : 8, "Colour" : "Black","Retailer Name":"Gopal","Give discout":0},
                3 : {"Item Name" : "Pencil","Price Per Piece" : 3,"Quantity" : 10, "Colour" : "Black","Retailer Name":"Vishwa","Give discout":1},
                4 : {"Item Name" : "Notebook","Price Per Piece" : 20,"Quantity" : 15, "Colour" : "Paper unruled","Retailer Name":"Parasar","Give discout":0},
                5 : {"Item Name" : "fan","Price Per Piece" : 1000,"Quantity" : 2, "Colour" : "Purple","Retailer Name":"Singh","Give discout":50},
                6 : {"Item Name" : "Chair","Price Per Piece" : 340,"Quantity" : 10, "Colour" : "Black","Retailer Name":"Sonu","Give discout":20},
                7 : {"Item Name" : "Table","Price Per Piece" : 400,"Quantity" : 14, "Colour" : "Black","Retailer Name":"Sonu","Give discout":0},
                8 : {"Item Name" : "Samsung Mobile","Price Per Piece" : 10000,"Quantity" : 2, "Colour" : "Blue","Retailer Name":"Singh","Give discout":500},
                9 : {"Item Name" : "Redmi Headset","Price Per Piece" : 300,"Quantity" : 10, "Colour" : "Blue","Retailer Name":"Singh","Give discout":0},
               10 : {"Item Name" : "Earphone","Price Per Piece" : 100,"Quantity" : 2, "Colour" : "Purple","Retailer Name":"Singh","Give discout":0},
               11 : {"Item Name" : "Water Bottle","Price Per Piece" : 150,"Quantity" : 10, "Colour" : "Black","Retailer Name":"Sonu","Give discout":10},
               12 : {"Item Name" : "Electric Switch","Price Per Piece" : 15,"Quantity" : 10, "Colour" : "Purple","Retailer Name":"Singh","Give discout":0},
               13 : {"Item Name" : "Calculator","Price Per Piece" : 1000,"Quantity" : 10, "Colour" : "Blue","Retailer Name":"Singh","Give discout":50},
               14 : {"Item Name" : "Bucket","Price Per Piece" : 100,"Quantity" : 50, "Colour" : "Purple","Retailer Name":"Aman","Give discout":0},
               15 : {"Item Name" : "Mug","Price Per Piece" : 15,"Quantity" : 50, "Colour" : "Purple","Retailer Name":"Aman","Give discout":0},
               16 : {"Item Name" : "Bedsheet","Price Per Piece" : 200,"Quantity" : 10, "Colour" : "Blue Print","Retailer Name":"Anand","Give discout":10},
               17 : {"Item Name" : "Pillow","Price Per Piece" : 200,"Quantity" : 10, "Colour" : "Blue Print","Retailer Name":"Anand","Give discout":0},
               18 : {"Item Name" : "Electric Board","Price Per Piece" : 50,"Quantity" : 12, "Colour" : "White","Retailer Name":"Singh","Give discout":0},
               19 : {"Item Name" : "Brick","Price Per Piece" : 10,"Quantity" : 5000, "Colour" : "Purple","Retailer Name":"Munna","Give discout":0},
               20 : {"Item Name" : "Redmi Mobile","Price Per Piece" : 8000,"Quantity" : 2, "Colour" : "Black","Retailer Name":"Singh","Give discout":50},
               21 : {"Item Name" : "Lava Mobile","Price Per Piece" : 4000,"Quantity" : 2, "Colour" : "Purple","Retailer Name":"Singh","Give discout":50},
               22 : {"Item Name" : "Soni Mobile","Price Per Piece" : 9500,"Quantity" : 2, "Colour" : "Blue","Retailer Name":"Singh","Give discout":50},
               23 : {"Item Name" : "Soni Headset","Price Per Piece" : 500,"Quantity" : 10, "Colour" : "Purple","Retailer Name":"Singh","Give discout":0},
               24 : {"Item Name" : "Shirt","Price Per Piece" : 1000,"Quantity" : 20, "Colour" : "Black","Retailer Name":"Misra","Give discout":50},
               25 : {"Item Name" : "Pant","Price Per Piece" : 1000,"Quantity" : 25, "Colour" : "Black","Retailer Name":"Misra","Give discout":50},
               26 : {"Item Name" : "Frock","Price Per Piece" : 1000,"Quantity" : 21, "Colour" : "Black","Retailer Name":"Misra","Give discout":50},
               27 : {"Item Name" : "Jeans","Price Per Piece" : 1000,"Quantity" : 25, "Colour" : "White-Black","Retailer Name":"Misra","Give discout":50},
               28 : {"Item Name" : "Sweater","Price Per Piece" : 1500,"Quantity" : 21, "Colour" : "Purple","Retailer Name":"Misra","Give discout":60},
               29 : {"Item Name" : "Jacket","Price Per Piece" : 1100,"Quantity" : 22, "Colour" : "Black","Retailer Name":"Misra","Give discout":50},
               30 : {"Item Name" : "T-Shirt","Price Per Piece" : 500,"Quantity" : 51, "Colour" : "Red","Retailer Name":"Misra","Give discout":20},
               31 : {"Item Name" : "Electric Pipe","Price Per Piece" : 220,"Quantity" : 51, "Colour" : "Black","Retailer Name":"Singh","Give discout":21}}
        js = json.dumps(Item)
        fd = open("Records.json",'w')
        r = fd.write(js)
        fd.close()
        print("Thanks🤗😍All Item Refresh")
    else:
        print("Ok👌History Not Deleted")
    conn=str(input("Confirm➫Y/y To Delete Histoy Of Purchase Item In Inventory\nOr,Enter N/n➫If Not Want To delete\n"))
    if(conn=='Y' or conn=='y'):
        Sale = {}
        k=json.dumps(Sale)
        fd = open("Sales.json",'w')
        rd = fd.write(k)
        fd.close()
        print("Thanks🤗😍All Item Refresh")
    else:
        print("Ok👌History Not Deleted")
import json
import time
time_c=time.time()
time_m=time.ctime(time_c)
Item = json.load(open('Records.json'))
Sale = json.load(open('Sales.json'))
if(item_name==1):
    print("******************************")
    for i in Item:
        print("Item number",i,":",Item[i]["Item Name"])
    print("*******************************")
if(item_name==2):
    for i in Item:
        print("**********************************************")
        print("Item Number",i,":",Item[i]["Item Name"])
        print("Item Detail Available in Stock",Item[i])
        print("**********************************************")
if(item_name==3):
    import json
    
    in_item=int(input("Please Enter Code:101 📝Know Item Detail Again\n"))
    if(in_item==101):
        print("*********************************************")
        for i in Item:
            print("Item number",i,":",Item[i]["Item Name"])
        print("**********************************************")
        in_item=str(input("Please Enter Item Number: 📝You Want To Purchase\n")) 
        if(in_item in Item.keys()):
            print("------------------------------------------------------------")
            print("you want to order Item code:",in_item,"🗂️","Item Name:",Item[in_item]["Item Name"])
            print("------------------------------------------------------------")
            in_i=int(input("Enter Code:102 📝Complete Item Detail ➡️For Skip:Another Value\n"))
            if(in_i==102):
                print("****************************************************************************")
                print("You Select Item code :",in_item,"Item Name :",Item[in_item]["Item Name"])
                print("Item Price Per Piece :",Item[in_item]["Price Per Piece"])
                print("Total Item In Stock :",Item[in_item]["Quantity"])
                print("Discount For Today :",Item[in_item]["Give discout"])
                print("Colour of Item :",Item[in_item]["Colour"])
                print("Retailer Name :",Item[in_item]["Retailer Name"])
                if(Item[in_item]["Give discout"]>0):
                    print("Hurry up today Discount For This Item :",Item[in_item]["Give discout"])
                print("****************************************************************************")
            in_ii=str(input("Press: Yes or yes 📝If You Want To Buy\n"))
            if(in_ii=="Yes" or in_ii=="yes"):
                in_quan=int(input("Enter No. Quantity You Want To Order\n"))
                if(in_quan>0 and in_quan<=Item[in_item]["Quantity"]):
                    t_price=in_quan*Item[in_item]["Price Per Piece"]
                    t_dis=t_price-Item[in_item]["Give discout"]*in_quan
                    t_quantity=Item[in_item]["Quantity"]-in_quan
                    print("****************************************")
                    print("Total Price :",t_price)
                    print("After Discount 🏧Billing Price:",t_dis)
                    print("****************************************")
                    in_iii=str(input("Again Conform: Y or y To🛒Buy\n"))           
                    if(in_iii=="Y" or in_iii=="y"):
                        print("---------------------------------------")
                        print("╎Provide Us These Detail To Place Order╎")
                        print("---------------------------------------")
                        cus_name=str(input("Enter Your Name 📋Name-Xyz\n"))
                        address=str(input("Enter Your Address 📋Address-Abc\n"))
                        print("\n📝Note:->Pincode✢LAST 4 Digit Of Mobile Number Use To✍️Generate Transaction ID")
                        pin_code=str(input("Enter PinCode 📋PinCode-123456\n"))
                        m_no=str(input("Enter Mobile Number \n"))
                        last_m_no = m_no[-4:]
                        u_add=pin_code+last_m_no
                        print("\nThanks💖😍Order of your item Placed Successfully✨✨✨✨✨\n\n")
                        print("----------------")
                        print("╎Your🧾Invoice☟╎")
                        print("----------------")
                        print("┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈")
                        print("╎Your📋Transaction ID➤",u_add)
                        print("------------------------------------------------------------------------")
                        print("╎Custumber Name           :",cus_name)
                        print("╎Customber Address,Pincode:",address,",",pin_code)
                        print("╎-----------------------------------------------------------------------")
                        print("╎Total📦Quantity Order   :",in_quan)
                        print("╎Item Name                :",Item[in_item]["Item Name"])
                        print("╎-----------------------------------------------------------------------")
                        print("╎Time⏱️Of Purchase        :",time_m)
                        print("╎-----------------------------------------------------------------------")
                        print("╎Final🏧Billing Price     :",t_dis)
                        print("┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈")
                        print("\n\nThanks🤗🥰🛒Shopping👍😍")
                        Sale[str(len(Sale)+1)]={"Item Number":in_item,"Transaction ID":u_add,"Item Name" :Item[in_item]["Item Name"],"Billing Amount" :t_dis,"Quantity Ordered" :in_quan,"Retailer Name":Item[in_item]["Retailer Name"],"Customber Name":cus_name,"Customber Address":address,"Customber Mobile Number":m_no,"Time Of Purchase":time_m}
                        Item[in_item]["Quantity"]=t_quantity
                        k=json.dumps(Sale)
                        fd = open("Sales.json",'w')
                        rd = fd.write(k)
                        fd.close()
                        s = json.dumps(Item)
                        fd = open("Records.json",'w')
                        r = fd.write(s)
                        fd.close()
                    else:
                        print("Invalid🔥🖾😞Input")  
                else:
                    print("Sorry!😞 No Such Number of📦Quantity In Our Store")  
            else:
                print("Invalid🔥🖾😞Input")
        else:
            print("Sorry😞🖾🔥Such Item Not Found In Store")
    else:
        print("Invalid🔥🖾😞Input")
if(item_name==4):
    s=str(input("Enter Your Name Please Remember Your Name Is Your Password\n"))
    s_password=str(input("Enter Password 💡Hint: Password Is Your Name That You Have Entered Previous\n"))
    if(s==s_password):
        print("\n🏹Congratulations 🎉 You Have Authorized To Add New Item")
        print("Warning ⚠️ Please Use Another Product Id,Present Product Id Are :",Item.keys())
        item_id = str(input("Enter New Product id\n"))
        if(item_id in Item.keys()):
            print("Soory😞You Have Entered Either Item Already Exist or Invaid Product Id")
        else:
            name_it = str(input("Enter Item Name\n"))
            pr = int(input("Enter Price Per Piece Of Item\n"))
            qn = int(input("Enter Quantity To Sell Item\n"))
            col= str(input("Enter Colour Of Item\n"))
            retailer_nm=str(input("Enter Retailer Name\n"))
            disc=int(input("Enter Discount That You Want To Give Customber 📝Note:If No Discount Then Enter 0\n"))
            Item[item_id] = {"Item Name" :name_it,"Price Per Piece" : pr,"Quantity" : qn, "Colour" : col,"Retailer Name":retailer_nm,"Give discout":disc}
            js = json.dumps(Item)
            fd = open("Records.json",'w')
            r = fd.write(js)
            fd.close()
            print("Thanks🤗😍New Item Added In store")
    else:
        print("Soory😞🙇🏽‍You Have Entered Wrong Password")
if(item_name==5):
    s=str(input("Enter Your Name Please Remember Your Name Is Your Password\n"))
    s_password=str(input("Enter Password 💡Hint: Password Is Your Name That You Have Entered Previous\n"))
    if(s==s_password):
        print("\n🏹Congratulations 🎉 You Have Authorized Update Item In Inventory")
        print("Present Product Id In Store :",Item.keys())
        item_id = str(input("Enter Product id That You Want To Update Quantity\n"))
        if(item_id in Item.keys()):
            print("------------------------------------------------------------")
            print("you want to Change Item Number:",item_id,"🗂️","Item Name:",Item[item_id]["Item Name"])
            print("Present📦Quantity in Store:",Item[item_id]["Quantity"])
            print("------------------------------------------------------------")
            q_id=str(input("Enter➫I/i To Increase Quantity in Item\nEnter➫D/d Decrease Quantity in Item\nEnter➫U/u Direct Update With New Quantity\n"))
            if(q_id=="I" or q_id=="i"):
                qn = int(input("Enter Quantity want To Increase\n"))
                qt=Item[item_id]["Quantity"]+qn
                Item[item_id]["Quantity"]=qt
                js = json.dumps(Item)
                fd = open("Records.json",'w')
                r = fd.write(js)
                fd.close()
                print("Thanks🤗😍Quantity Updated In Store")
            if(q_id=="D" or q_id=="d"):
                qn = int(input("Enter Quantity want To Decrease\n"))
                qt=Item[item_id]["Quantity"]-qn
                if(qt>=0):
                    Item[item_id]["Quantity"]=qt
                    js = json.dumps(Item)
                    fd = open("Records.json",'w')
                    r = fd.write(js)
                    fd.close()
                    print("Thanks🤗😍Quantity Updated In Store")
                else:
                    print("Soory😞Negative Quantity Not Allow To Update in Store")  
            if(q_id=="U" or q_id=="u"):
                qn = int(input("Enter Quantity want To Update With New\n"))
                Item[item_id]["Quantity"]=qn
                js = json.dumps(Item)
                fd = open("Records.json",'w')
                r = fd.write(js)
                fd.close()
                print("Thanks🤗😍Quantity Updated In Store")            
        else:
            print("Soory😞You Have Entered Either Item Not Exist or Invaid Product Id")
    else:
        print("Soory😞🙇🏽‍You Have Entered Wrong Password") 
if(item_name==7): 
    s=str(input("Enter Your Name Please Remember Your Name Is Your Password\n"))
    s_password=str(input("Enter Password 💡Hint: Password Is Your Name That You Have Entered Previous\n"))
    if(s==s_password):
        print("\n🏹Congratulations 🎉 You Have Authorized Remove Item In Inventory")
        print("Present Product Id In Store :",Item.keys())
        item_id = str(input("Enter Product id That You Want To Remove\n"))
        if(item_id in Item.keys()):
            print("------------------------------------------------------------")
            print("you want to Remove Item Number:",item_id,"🗂️","Item Name:",Item[item_id]["Item Name"])
            print("------------------------------------------------------------")
            r_id=str(input("Confirm➫Y/y To Remove Item In Store\n"))
            if(r_id=="Y" or r_id=="y"):
                del Item[item_id]
                js = json.dumps(Item)
                fd = open("Records.json",'w')
                r = fd.write(js)
                fd.close()
                print("Thanks🤗😍Item Removed From Store") 
            else:
                print("Invalid🔥🖾😞Input")
        else:
            print("Soory😞You Have Entered Either Item Not Exist or Invaid Product Id")
    else:
        print("Soory😞🙇🏽‍You Have Entered Wrong Password")         
if(item_name>=8 or item_name<=0):
    print("Something😔Went❌Wrong")
# Out:
#  ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
# ╎⫷𝓦𝓮𝓵𝓬𝓸𝓶𝓮 T♥O 𝓢🎀𝓢𝓱𝓸𝓹⫸╎
#  ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
# Enter➫1 For Name of the Item Present in Stock
# Enter➫2 For All Item Detail Of Price,Quantity,Colour,Retailer Name,Discount
# Enter➫3 If You Want To Order/Purchase Any Item
# Enter➫4 If You Want To Add New Item In Inventory
# Enter➫5 If You Want To Update Quatity(Increase/Decrease) In Inventory
# Enter➫6 For Refresh Item And Delete History Of Purchase and Add Item
# Enter➫7 For Remove Item From Store
#
# Thanks for visit😊
# 3
# Please Enter Code:101 📝Know Item Detail Again
# 101
# *********************************************
# Item number 1 : Book
# Item number 2 : Pen
# Item number 3 : Pencil
# Item number 4 : Notebook
# Item number 5 : fan
# Item number 6 : Chair
# Item number 7 : Table
# Item number 8 : Samsung Mobile
# Item number 9 : Redmi Headset
# Item number 10 : Earphone
# Item number 11 : Water Bottle
# Item number 12 : Electric Switch
# Item number 13 : Calculator
# ...
